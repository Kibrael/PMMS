# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')


col_names = ['week', '30yr FRM', '30 yr p&f', '15yr FRM', '15yr p&f', '5/1 ARM', '5/1 ARM p&f', '5/1 ARM margin',  '1yr ARM', '1yr ARM p&f', '1yr ARM margin', '30yr FRM 1yr ARM spread']

rates_2015 = pd.read_csv('PMMS2015.csv', names=col_names, header=0)
rates_2015['date'] = rates['week'] + '/2015'

rates_2014 = pd.read_csv('PMMS2014.csv', names=col_names, header=0)
rates_2014['date'] = rates_2014['week'] + '/2014'

rates_2013 = pd.read_csv('PMMS2013.csv', names=col_names, header=0)
rates_2013['date'] = rates_2013['week'] + '/2013'

rates_2012 = pd.read_csv('PMMS2012.csv', names=col_names, header=0)
rates_2012['date'] = rates_2012['week'] + '/2012'

rates_2011 = pd.read_csv('PMMS2011.csv', names=col_names, header=0)
rates_2011['date'] = rates_2011['week'] + '/2011'

rates_2010 = pd.read_csv('PMMS2010.csv', names=col_names, header=0)
rates_2010['date'] = rates_2011['week'] + '/2010'

all_rates = pd.concat([rates_2010, rates_2011, rates_2012, rates_2013, rates_2014, rates_2015])

# %%
all_rates.plot(x='date', y='30yr FRM')

# %%
all_rates.plot(x='date',subplots=True, figsize=(15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x114570ed0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1145ba350>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x113994910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11467a910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11474f850>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1147b54d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x114835650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1148b8490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x114925410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1149a9250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x114a0e210>], dtype=object)

# %%
# Out:
# (52, 13)
